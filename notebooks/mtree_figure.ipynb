# %%
import drawSvg as draw
import os

d = draw.Drawing(700, 700, origin='center', displayInline=False)

d.append(draw.Rectangle(-250, -250, 500, 500, fill='none', stroke_width=1, stroke='black'))

# 1
d.append(draw.Circle(-175, -175, 55, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-200, -100, 25, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-150, -150, 25, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-175, -50, 50, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-75, -80, 83, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-75, -200, 50, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-100, -200, 40, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-155, -225, 30, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-225, -125, 45, fill='none', stroke_width=1, stroke='green'))

# 2
d.append(draw.Circle(-125, 215, 75, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-85, 225, 55, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-200, 150, 54, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-185, 225, 70, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-145, 125, 40, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-105, 125, 25, fill='none', stroke_width=1, stroke='green'))

# 3
d.append(draw.Circle(-100, 50, 40, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-140, 50, 30, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-100, 90, 20, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-40, 60, 14, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-100, 8, 30, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(-60, 35, 25, fill='none', stroke_width=1, stroke='green'))

# 4
d.append(draw.Circle(-15, 135, 82, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(40, 115, 50, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(20, 80, 40, fill='none', stroke_width=1, stroke='green'))

# 5
d.append(draw.Circle(25, -100, 75, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(15, -200, 70, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(85, -200, 40, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(85, -155, 30, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(110, -125, 25, fill='none', stroke_width=1, stroke='green'))

# 6
d.append(draw.Circle(200, 0, 100, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(170, 80, 80, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(0, 0, 70, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(65, 0, 60, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(90, -60, 50, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(180, -90, 40, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(160, -150, 30, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(190, -135, 20, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(100, 150, 10, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Circle(100, 120, 30, fill='none', stroke_width=1, stroke='green'))

d.append(draw.Circle(-125, -125, 150, fill='none', stroke_width=1, stroke='red'))
d.append(draw.Circle(-150, 200, 125, fill='none', stroke_width=1, stroke='red'))
d.append(draw.Circle(-100, 50, 75, fill='none', stroke_width=1, stroke='red'))
d.append(draw.Circle(0, 125, 100, fill='none', stroke_width=1, stroke='red'))
d.append(draw.Circle(25, -150, 125, fill='none', stroke_width=1, stroke='red'))
d.append(draw.Circle(100, 0, 200, fill='none', stroke_width=1, stroke='red'))

d.setPixelScale(1)

d.saveSvg(os.path.expanduser('~/Downloads/mtree.svg'))

# %%
import drawSvg as draw
import os

d = draw.Drawing(550, 550, origin='center', displayInline=False)

# Level 3 circles
# 1
d.append(draw.Circle(-180, -135, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-185, -150, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-170, -110, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-140, -145, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-150, -115, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-165, -120, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-160, -155, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-155, -145, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-145, -140, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-175, -130, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-185, -120, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-145, -130, 2, fill='orange', stroke_width=1, stroke='orange'))

# 2
d.append(draw.Circle(-100, -35, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-100, -15, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-120, -25, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-110, -10, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-115, -15, 2, fill='orange', stroke_width=1, stroke='orange'))

# 3
d.append(draw.Circle(-80, -165, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-60, -155, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-85, -140, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-65, -135, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-65, -145, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(-75, -160, 2, fill='orange', stroke_width=1, stroke='orange'))

# 4
d.append(draw.Circle(120, 160, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(130, 140, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(100, 100, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(110, 180, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(80, 145, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(70, 150, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(40, 115, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(40, 190, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(80, 195, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(100, 155, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(55, 130, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(115, 165, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(125, 170, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(110, 150, 2, fill='orange', stroke_width=1, stroke='orange'))


# 5
d.append(draw.Circle(130, -100, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(110, -130, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(150, -150, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(80, -45, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(90, -50, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(100, -70, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(70, -100, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(50, -120, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(130, -55, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(130, -130, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(160, -70, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(170, -30, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(180, -90, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(185, -60, 2, fill='orange', stroke_width=1, stroke='orange'))
d.append(draw.Circle(185, -110, 2, fill='orange', stroke_width=1, stroke='orange'))

# Level 2 circles
d.append(draw.Circle(-165, -130, 35, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Line(-165, -130, -185, -102, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(-185, -102, 2, fill='red', stroke_width=1, stroke='red'))

d.append(draw.Circle(-110, -25, 20, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Line(-110, -25, -90, -25, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(-90, -25, 2, fill='red', stroke_width=1, stroke='red'))

d.append(draw.Circle(-70, -150, 25, fill='none', stroke_width=1, stroke='green'))
d.append(draw.Line(-70, -150, -70, -175, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(-70, -175, 2, fill='red', stroke_width=1, stroke='red'))

# Level 1 circles
# 1
d.append(draw.Circle(-115, -96, 100, fill='none', stroke_width=1, stroke='blue'))
d.append(draw.Line(-115, -96, -15, -96, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(-15, -96, 2, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Line(-115, -96, -165, -130, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Circle(-110, -25, 2, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Line(-115, -96, -110, -25, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Circle(-165, -130, 2, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Line(-115, -96, -70, -150, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Circle(-70, -150, 2, fill='blue', stroke_width=1, stroke='blue'))
d.append(draw.Text('A', 16, -120, 10, fill='blue'))

# 2
d.append(draw.Circle(90, 150, 70, fill='none', stroke_width=1, stroke='blue'))
d.append(draw.Line(90, 150, 130, 93, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(130, 93, 2, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Text('B', 16, 0, 160, fill='blue'))

# 3
d.append(draw.Circle(110, -82, 85, fill='none', stroke_width=1, stroke='blue'))
d.append(draw.Line(110, -82, 145, -5, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(145, -5, 2, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Text('C', 16, 200, -70, fill='blue'))

# Outer circle
d.append(draw.Circle(0, 0, 250, fill='none', stroke_width=1, stroke='black'))
d.append(draw.Line(0, 0, -177, 177, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Circle(-177, 177, 2, fill='red', stroke_width=1, stroke='red'))
d.append(draw.Text('R', 16, -76, 80, fill='red'))
d.append(draw.Line(0, 0, -115, -96, fill='black', stroke_width=1, stroke='black'))
d.append(draw.Circle(-115, -96, 2, fill='black', stroke_width=1, stroke='black'))
d.append(draw.Line(0, 0, 90, 150, fill='black', stroke_width=1, stroke='black'))
d.append(draw.Circle(90, 150, 2, fill='black', stroke_width=1, stroke='black'))
d.append(draw.Line(0, 0, 110, -82, fill='black', stroke_width=1, stroke='black'))
d.append(draw.Circle(110, -82, 2, fill='black', stroke_width=1, stroke='black'))

d.setPixelScale(1)

d.saveSvg(os.path.expanduser('~/Downloads/mtree_structure.svg'))
